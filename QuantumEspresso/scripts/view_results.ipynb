# %%
## imports

import numpy as np
from pathlib import Path
from ase.build import bulk
from ase.io import write
from ase.calculators.espresso import Espresso, EspressoProfile
from ase.visualize import view
from ase.visualize import view as viewer
import sys
from ase.io import read

helper_path = Path("/Users/famkepotze/Desktop/3S/NV-center-3S/QuantumEspresso/")
sys.path.insert(0, str(helper_path))
from helper import supercell_size

# %%
## view structures

selected_supercell_size = supercell_size[3]  # Choose the desired supercell size (1, 2, or 3)

atoms = read(f"/Users/famkepotze/Desktop/3S/NV-center-3S/QuantumEspresso/results/raw_structures/NV_{selected_supercell_size[0]}x{selected_supercell_size[1]}x{selected_supercell_size[2]}.xyz")

view(atoms, viewer="x3d")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 ## view structures
#       3 selected_supercell_size = supercell_size[3]  # Choose the desired supercell size (1, 2, or 3)
# ----> 5 atoms = read(f"/Users/famkepotze/Desktop/3S/NV-center-3S/QuantumEspresso/results/optimized/NV_{selected_supercell_size[0]}x{selected_supercell_size[1]}x{selected_supercell_size[2]}.xyz")
#       7 view(atoms, viewer="x3d")
#
# File ~/anaconda3/envs/3S/lib/python3.11/site-packages/ase/io/formats.py:780, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     778 if index is None:
#     779     index = -1
# --> 780 format = format or filetype(filename, read=isinstance(filename, str))
#     782 io = get_ioformat(format)
#     783 if isinstance(index, (slice, str)):
#
# ...

# %%
## DOS results
